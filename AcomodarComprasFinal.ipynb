# %%
# importing package
from __future__ import division
import os
import re
import sys
import nltk
import gensim
import pprint
import shutil
import PyPDF2
import textract
import unicodedata
# importing package functions
from nltk import *
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#reload(sys)
#sys.setdefaultencoding('utf8')
# Define base files to compare

# %%
path = '/home/sistemas/Compras/'
base = 'Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/'
recover = 'Recuperados/pdf/renombrar/'
compareFiles = [] #"/home/sistemas/Documentos/Scripts/base.pdf"]
raw_documents = []
TRindex = []

# %%
for i in os.listdir(path+base):
    ruta = path+base+i
    if not os.path.isdir(ruta) and ".pdf" in i:
        compareFiles.append(ruta)
    elif os.path.isdir(ruta):
        for j in os.listdir(ruta):
            subruta = ruta+"/"+j
            if not os.path.isdir(subruta) and ".pdf" in j:
                compareFiles.append(subruta)
            elif os.path.isdir(subruta):
                for k in os.listdir(subruta):
                    subsubruta = subruta+"/"+k
                    if not os.path.isdir(subsubruta) and ".pdf" in k:
                        compareFiles.append(subsubruta)

# %%
for i in compareFiles:
    if "TR" in i:
        TRindex.append(compareFiles.index(i)) #a = 1 #," "+i #print a,":"+i #a+=1
        print compareFiles.index(i)," ",i
# Out:
# 2   /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/TR 15960 Makicop 290 Toner Sharp MX-500 23Feb17.pdf
# 4   /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/TR 15960 FACT. M9129 MAKICOP.pdf
# 6   /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/scannedTR15960FACTM9129MAKICOP.pdf
# 14   /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/04 Abril/Makicop 293 Equipo Sharp 363 OC 1056 17Abr17/TR 16270 Makicop 293 Equipo Sharp 363 OC 1056 17Abr17.pdf
# 53   /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/01 Enero/Makicop 289 Toner Sharp 2610 31Ene17/TR 15957 FACT. M 8961 MAKICOP.pdf
# ...

# %%
print len(compareFiles)
# Out:
# 59

# %%
if not isinstance(path,str):
    print "yei"
else:
    print "No"
# Out:
# No

# %%
for i in TRindex:
    count = 0
    text = ""
    print compareFiles[i]
    pdfFileObj = open(compareFiles[i],'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    num_pages = pdfReader.numPages
    while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count +=1
            text += pageObj.extractText()
    if text != "":
        text = text
        text=unicodedata.normalize('NFKD',text).encode('ascii','ignore')
        raw_documents.append(text)
    else:
        text = textract.process(compareFiles[i], method='tesseract', language='eng')
        #if not isinstance(text,str):
        #    text=unicodedata.normalize('NFKD',text).encode('ascii','ignore')
        raw_documents.append(text)
# Out:
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/TR 15960 Makicop 290 Toner Sharp MX-500 23Feb17.pdf
# ...
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/TR 15960 FACT. M9129 MAKICOP.pdf
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/scannedTR15960FACTM9129MAKICOP.pdf
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/04 Abril/Makicop 293 Equipo Sharp 363 OC 1056 17Abr17/TR 16270 Makicop 293 Equipo Sharp 363 OC 1056 17Abr17.pdf
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/01 Enero/Makicop 289 Toner Sharp 2610 31Ene17/TR 15957 FACT. M 8961 MAKICOP.pdf
# ...

# %% [markdown]
# for i in compareFiles:
#         count = 0
#         text = ""
#         pdfFileObj = open(i,'rb')
#         pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#         num_pages = pdfReader.numPages
#         while count < num_pages:
#                 pageObj = pdfReader.getPage(count)
#                 count +=1
#                 text += pageObj.extractText()
#         if text != "":
#             text = text
#             text=unicodedata.normalize('NFKD',text).encode('ascii','ignore')
#             raw_documents.append(text)
#         else:
#             text = textract.process(i, method='tesseract', language='eng')
#             #if not isinstance(text,str):
#             #    text=unicodedata.normalize('NFKD',text).encode('ascii','ignore')
#             raw_documents.append(text)

# %%
print compareFiles[3]
# Out:
# /home/sistemas/Compras/Pedidos Mayoristas/Pedidos Mayoristas 2017/Makicop/02 Febrero/Makicop 290 Toner Sharp MX-500 23Feb17/Recepcion Compra No.910.pdf

# %%
#gen_docs = [[w.lower() for w in word_tokenize(text)] 
#            for text in raw_documents]
for text in raw_documents:
    for w in word_tokenize(text):
        print raw_documents.index(text),": ",w.lower
        
print gen_docs
# Generate Dictionari
dictionary = gensim.corpora.Dictionary(gen_docs)
# Corpus to compare
corpus = [dictionary.doc2bow(gen_doc) for gen_doc in gen_docs]
# TF-ID method
tf_idf = gensim.models.TfidfModel(corpus)
# Sims
sims = gensim.similarities.Similarity('/home/sistemas/Documentos/Scripts/',tf_idf[corpus],
                                      num_features=len(dictionary))
# Out:
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1b10>
# 0 :  <built-in method lower of str object at 0x7fa7d0f73030>
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1fc0>
# 0 :  <built-in method lower of str object at 0x7fa7d0df0210>
# 0 :  <built-in method lower of str object at 0x7fa8151913f0>
# 0 :  <built-in method lower of str object at 0x7fa7d0f6d3a0>
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1060>
# 0 :  <built-in method lower of str object at 0x7fa8150f9d50>
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1f00>
# 0 :  <built-in method lower of str object at 0x7fa7d0fcde30>
# 0 :  <built-in method lower of str object at 0x7fa7d0f6d058>
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1bd0>
# 0 :  <built-in method lower of str object at 0x7fa7d0f6d9e0>
# 0 :  <built-in method lower of str object at 0x7fa7d0f6d0f8>
# 0 :  <built-in method lower of str object at 0x7fa7d0fc1d50>
# ...

# %%
for i in raw_documents:
    print i
# Out:
# Makicop, SA de CV
# i Morena No. 108 DeI VaIIe Centro
# ’ _ Benlto Juarez Cludad de Mexico, GP 03100
# MAK911213KM3
# www.makicop com mx TeI. 5543-1510
#
#
#
# Factura M 9129
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ientews366 W" ERECV RECEETOR; 7ED8050817273k0 WW" I=echa yam; 7 24/02/2017T09'03 2177 I
# EAO DIGITAL SOLUTIONS. S A. DE CV. Fecha y no 24/02/2 7T09 as 36 7*
# We 5'“. " 5‘4MA96593033-754F-
#
# <DOMICILIO FISCAL> IQQD7-17SB4FD67FAC
#
# SEBASTIAN DEL PIOMBO No. 82 Int_ 2 No Cenmcado SAT I0000|000000401041203
#
# NONOALCO No Cemncado oucmooooommmsasém
#
# BENITO JUAREZ Melodo de page: 93 NA
#
# CIudad de México GP 03700 Cuenla: ‘
#
# Lugar de expedicién‘ Ciudad de Méxlco Régimen generaI de ley de personas morales Page en una soIa exhlbic on
# _Codigc Cant. Unidad Descripcién Precio U. lmporte
# IVIX~500NT 5 00 PZ TONER NEGRO 2/E/0/0 1,134 610 5,673 05
#
# TONER NEGRO 2/E/0/0
# ...

# %%
st =  "abcdefghij"
print st[-10:]
# Out:
# abcdefghij

# %%
for i in compareFiles:
    i = i.split("/")
    print i[-1]
# Out:
# Acuse F. M 9129.pdf
# OC Autorizada.pdf
# TR 15960 Makicop 290 Toner Sharp MX-500 23Feb17.pdf
# Recepcion Compra No.910.pdf
# TR 15960 FACT. M9129 MAKICOP.pdf
# Santi 920 Makicop 290 Toner Sharp MX-500 23Feb17.pdf
# scannedTR15960FACTM9129MAKICOP.pdf
# Factura_M9128.pdf
# EDS0508123K0_FAC_EAO15527_20170130.pdf
# Santi 988 Makicop 288 Prestamo Equipo MX-C300W 23Feb17.pdf
# Santi 1029 Makicop 292 Consumible Sharp C-300 04Abr17.pdf
# Factura_M9380.pdf
# Recepcion de Orden de Compra.pdf
# Santi 1056 Makicop 293 Equipo Sharp 363 17Abr17.pdf
# TR 16270 Makicop 293 Equipo Sharp 363 OC 1056 17Abr17.pdf
# Factura_M9436.pdf
# Factura_M9128.pdf
# Estado de Cuenta y Respaldos Makicop.pdf
# Factura_M9380.pdf
# Factura_M7732.pdf
# Factura_M9383.pdf
# MAK911213KM3_Factura_M6068_20160106.pdf
# MAK911213KM3_Factura_M7313_20160620.pdf
# Factura_M7667.pdf
# MAK911213KM3_Factura_M6029_20151223.pdf
# Acuse F. M 10062.pdf
# OC Autorizada.pdf
# Factura_M10062.pdf
# Recepcion de Orden de Compra.pdf
# ...

# %%
print raw_documents
# Out:
# ['Makicop, SA de CV\ni Morena No. 108 DeI VaIIe Centro\n\xe2\x80\x99 _ Benlto Juarez Cludad de Mexico, GP 03100\nMAK911213KM3\nwww.makicop com mx TeI. 5543-1510\n\n   \n\nFactura M 9129\n\n \n\n \n\n    \n\n \n\n \n\n   \n  \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n  \n  \n\n    \n\n \n\n \n\nIentews366 W" ERECV RECEETOR; 7ED8050817273k0 WW" I=echa yam; 7 24/02/2017T09\'03 2177 I\nEAO DIGITAL SOLUTIONS. S A. DE CV. Fecha y no 24/02/2 7T09 as 36 7*\nWe 5\'\xe2\x80\x9c. " 5\xe2\x80\x984MA96593033-754F-\n\n<DOMICILIO FISCAL> IQQD7-17SB4FD67FAC\n\nSEBASTIAN DEL PIOMBO No. 82 Int_ 2 No Cenmcado SAT I0000|000000401041203\n\nNONOALCO No Cemncado oucmooooommmsas\xc3\xa9m\n\nBENITO JUAREZ Melodo de page: 93 NA\n\nCIudad de M\xc3\xa9xico GP 03700 Cuenla: \xe2\x80\x98\n\nLugar de expedici\xc3\xa9n\xe2\x80\x98 Ciudad de M\xc3\xa9xlco R\xc3\xa9gimen generaI de ley de personas morales Page en una soIa exhlbic on\n_Codigc Cant. Unidad Descripci\xc3\xa9n Precio U. lmporte\nIVIX~500NT 5 00 
# ...

# %%
for i in os.listdir(path+base):
    if os.path.isdir(path+base+i):
        print i
        for j in os.listdir(path+base+i):
            if os.path.isdir(path+base+i+"/"+j):
                print "\t"+"|-"+j
                for k in os.listdir(path+base+i+"/"+j):
                    if os.path.isdir(path+base+i+"/"+j+"/"+k):
                        print "\t\t"+"|-"+k
                    elif ".pdf" in k:
                        print "\t\t"+"|-"+k
            elif ".pdf" in j:
                print "\t"+"|-"+j
    elif ".pdf" in i:
        print i
