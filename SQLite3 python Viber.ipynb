# %%
import sqlite3

# %%
conn = sqlite3.connect('/home/developer/Documentos/ViberAna/525564994886/viber.db')

# %%
tables = "Calls,ChatsMetaData,Events,Messages,Versions,ChatInfo,Contact,EventsMetaData,RecycleBin,ChatRecovery,DownloadFile,LikeRelation,Settings,ChatRelation,EventInfo,MessageInfo,UploadFile"
tables = tables.split(",")

# %%
Calls = conn.execute("SELECT * from Calls")
ChatsMetaData = conn.execute("SELECT * from ChatsMetaData")
Events = conn.execute("SELECT * from Events")
Messages = conn.execute("SELECT * from Messages")
Versions = conn.execute("SELECT * from Versions")
ChatInfo = conn.execute("SELECT * from ChatInfo")
Contact = conn.execute("SELECT * from Contact")
EventsMetaData = conn.execute("SELECT * from EventsMetaData")
RecycleBin = conn.execute("SELECT * from RecycleBin")
ChatRecovery = conn.execute("SELECT * from ChatRecovery")
DownloadFile = conn.execute("SELECT * from DownloadFile")
LikeRelation = conn.execute("SELECT * from LikeRelation")
Settings = conn.execute("SELECT * from Settings")
ChatRelation = conn.execute("SELECT * from ChatRelation")
EventInfo = conn.execute("SELECT * from EventInfo")
MessageInfo = conn.execute("SELECT * from MessageInfo")
UploadFile = conn.execute("SELECT * from UploadFile")

# %%
tables = conn.execute("SELECT name FROM sqlite_master WHERE type='table'")

# %%
for i in tables:
    print(i)
# Out:
# ('Contact',)
# ('sqlite_sequence',)
# ('Settings',)
# ('ChatInfo',)
# ('ChatRelation',)
# ('Events',)
# ('Messages',)
# ('Calls',)
# ('DownloadFile',)
# ('UploadFile',)
# ('Versions',)
# ('ChatRecovery',)
# ('EventsMetaData',)
# ('LikeRelation',)
# ('RecycleBin',)
# ('ChatsMetaData',)

# %%
tableSchema = conn.execute("PRAGMA table_info(Messages);")

# %%
for i in tableSchema:
    print(i[1])
# Out:
# EventID
# Type
# Status
# Subject
# Body
# Flag
# PayloadPath
# ThumbnailPath
# StickerID
# PttID
# PttStatus
# Duration
# PGMessageId
# PGIsLiked
# PGLikeCount
# Info
# AppId
# ClientFlag

# %%
calls = []
chatsmetadata = []
events = []
messages = []
versions = []
chatinfo = []
contact = []
eventsmetadata = []
recyclebin = []
chatrecovery = []
downloadfile = []
likerelation = []
settings = []
chatrelation = []
eventinfo = []
messageinfo = []
uploadfile = []

# %%
for row in Calls:
    calls.append(row)
    
for row in ChatsMetaData:
    chatsmetadata.append(row)
    
for row in Events:
    events.append(row)
    
for row in Messages:
    messages.append(row)
    
for row in Versions:
    versions.append(row)
    
for row in ChatInfo:
    chatinfo.append(row)
    
for row in Contact:
    contact.append(row)
    
for row in EventsMetaData:
    eventsmetadata.append(row)
    
for row in RecycleBin:
    recyclebin.append(row)
    
for row in ChatRecovery:
    chatrecovery.append(row)
    
for row in DownloadFile:
    downloadfile.append(row)
    
for row in LikeRelation:
    likerelation.append(row)
    
for row in Settings:
    settings.append(row)
    
for row in ChatRelation:
    chatrelation.append(row)
    
for row in EventInfo:
    eventinfo.append(row)
    
for row in MessageInfo:
    messageinfo.append(row)
    
for row in UploadFile:
    uploadfile.append(row)

# %%
print("calls:{}".format(len(calls)))
print("chatsmetadata:{}".format(len(chatsmetadata)))
print("events:{}".format(len(events)))
print("messages:{}".format(len(messages)))
print("versions:{}".format(len(versions)))
print("chatinfo:{}".format(len(chatinfo)))
print("contact:{}".format(len(contact)))
print("eventsmetadata:{}".format(len(eventsmetadata)))
print("recyclebin:{}".format(len(recyclebin)))
print("chatrecovery:{}".format(len(chatrecovery)))
print("downloadfile:{}".format(len(downloadfile)))
print("likerelation:{}".format(len(likerelation)))
print("settings:{}".format(len(settings)))
print("chatrelation:{}".format(len(chatrelation)))
print("eventinfo:{}".format(len(eventinfo)))
print("messageinfo:{}".format(len(messageinfo)))
print("uploadfile:{}".format(len(uploadfile)))
# Out:
# calls:2
# chatsmetadata:45
# events:177001
# messages:176999
# versions:1
# chatinfo:105
# contact:269
# eventsmetadata:66
# recyclebin:0
# chatrecovery:0
# downloadfile:47508
# likerelation:214
# settings:67
# chatrelation:509
# eventinfo:177001
# messageinfo:176999
# uploadfile:436

# %%
#for i in messageinfo[0]:
print(messageinfo[176998])#i)
print("\n\n")    
for i in range(176990,176999):
    mensaje = ""
    for j in messages[i]:
        mensaje += str(j)+" "
    print("{}\n".format(mensaje))
        
print("\n\n")
print(contact[0])
for i in contact:
    print(i[4],i[6])
# Out:
# (184007, 1563819393234, 0, 0, 5334154838075831653, 5334154838075831653, 0, 0, 0, 0, 33, '4693798549505532078', 1, 0, None, 'En cfe', 8, 1, None, None, 0, None, 0, 0, 171, 0, 68, 0, 0, 0, '{}', 0, 1)
#
#
#
# 183999 1 0 None
# https://www.google.com/maps/place/19.3688637,-99.1662096/@19.3688637,-99.1662096,18z 0 None None 0 None 0 0 0 0 0  0 1
#
# 184000 1 0 None ya la probé hace rato, y asi sigue. Voy a reenviar el correo para que autorizen llevarla a revisión. 4104 None None 0 None 0 0 0 0 0  0 1
#
# 184001 1 0 None voy de salida de mascotas y compañía corporativo granada 8 None None 0 None 0 0 0 0 0 {} 0 1
#
# 184002 1 0 None
# https://www.google.com/maps/place/19.3688637,-99.1662096/@19.3688637,-99.1662096,18z 0 None None 0 None 0 0 0 0 0  0 1
#
# 184003 4 130 None  0 None None 407 0 0 0 0 0 0  0 1
#
# 184004 1 0 None Entonces me voy a la oficina por los coples 8 None None 0 None 0 0 0 0 0 {} 0 1
#
# 184005 4 0  None 8 None None 3900 None 0 0 0 0 0 {} 0 1
#
# 184006 1 0 None CFE
# ...

# %%
for i in tables:
    print("print(\"{}:{{}}\".format(len({})))".format(i.lower(),i.lower()))
# Out:
# print("calls:{}".format(len(calls)))
# print("chatsmetadata:{}".format(len(chatsmetadata)))
# print("events:{}".format(len(events)))
# print("messages:{}".format(len(messages)))
# print("versions:{}".format(len(versions)))
# print("chatinfo:{}".format(len(chatinfo)))
# print("contact:{}".format(len(contact)))
# print("eventsmetadata:{}".format(len(eventsmetadata)))
# print("recyclebin:{}".format(len(recyclebin)))
# print("chatrecovery:{}".format(len(chatrecovery)))
# print("downloadfile:{}".format(len(downloadfile)))
# print("likerelation:{}".format(len(likerelation)))
# print("settings:{}".format(len(settings)))
# print("chatrelation:{}".format(len(chatrelation)))
# print("eventinfo:{}".format(len(eventinfo)))
# print("messageinfo:{}".format(len(messageinfo)))
# print("uploadfile:{}".format(len(uploadfile)))

# %%
for i in tables:
    print("{} = conn.execute(\"SELECT * from {}\")".format(i,i))
# Out:
# Calls = conn.execute("SELECT * from Calls")
# ChatsMetaData = conn.execute("SELECT * from ChatsMetaData")
# Events = conn.execute("SELECT * from Events")
# Messages = conn.execute("SELECT * from Messages")
# Versions = conn.execute("SELECT * from Versions")
# ChatInfo = conn.execute("SELECT * from ChatInfo")
# Contact = conn.execute("SELECT * from Contact")
# EventsMetaData = conn.execute("SELECT * from EventsMetaData")
# RecycleBin = conn.execute("SELECT * from RecycleBin")
# ChatRecovery = conn.execute("SELECT * from ChatRecovery")
# DownloadFile = conn.execute("SELECT * from DownloadFile")
# LikeRelation = conn.execute("SELECT * from LikeRelation")
# Settings = conn.execute("SELECT * from Settings")
# ChatRelation = conn.execute("SELECT * from ChatRelation")
# EventInfo = conn.execute("SELECT * from EventInfo")
# MessageInfo = conn.execute("SELECT * from MessageInfo")
# UploadFile = conn.execute("SELECT * from UploadFile")

# %%
for i in tables:
    print("{} = []".format(i.lower()))
# Out:
# calls = []
# chatsmetadata = []
# events = []
# messages = []
# versions = []
# chatinfo = []
# contact = []
# eventsmetadata = []
# recyclebin = []
# chatrecovery = []
# downloadfile = []
# likerelation = []
# settings = []
# chatrelation = []
# eventinfo = []
# messageinfo = []
# uploadfile = []

# %%
for i in tables:
    print("for row in {}:\n\t{}.append(row)\n".format(i,i.lower()))
# Out:
# for row in Calls:
# 	calls.append(row)
#
# for row in ChatsMetaData:
# 	chatsmetadata.append(row)
#
# for row in Events:
# 	events.append(row)
#
# for row in Messages:
# 	messages.append(row)
#
# for row in Versions:
# 	versions.append(row)
#
# for row in ChatInfo:
# 	chatinfo.append(row)
#
# for row in Contact:
# 	contact.append(row)
#
# for row in EventsMetaData:
# 	eventsmetadata.append(row)
#
# for row in RecycleBin:
# 	recyclebin.append(row)
#
# for row in ChatRecovery:
# 	chatrecovery.append(row)
#
# for row in DownloadFile:
# 	downloadfile.append(row)
#
# for row in LikeRelation:
# 	likerelation.append(row)
#
# for row in Settings:
# 	settings.append(row)
#
# for row in ChatRelation:
# 	chatrelation.append(row)
#
# for row in EventInfo:
# 	eventinfo.append(row)
#
# for row in MessageInfo:
# 	messageinfo.append(row)
#
# for row in UploadFile:
# 	uploadfile.append(row)
