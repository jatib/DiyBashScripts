# %%
import sqlite3

# %%
def connector(path):
    conn = sqlite3.connect(path)
    return conn

# %%
path = "/home/developer/Documentos/VIberAna2/525564994886/viber.db"
conn = connector(path)
c = conn.execute("SELECT * from Messages")
message = []

# %%
print(dir(c))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %%
for row in c:
    message.append(row)

# %%
len(message)
# Out:
# 176999

# %%
for i in range(175000,176999):
    print(message[i])
# Out:
# (182009, 1, 0, None, 'saliendo de EAO', 10, None, None, 0, None, 0, 0, 0, 0, 0, '{}', 0, 1)
# (182010, 1, 0, None, 'llegando a EAO', 10, None, None, 0, None, 0, 0, 0, 0, 0, '{}', 0, 1)
# (182011, 1, 0, None, 'gracias compa descansa', 10, None, None, 0, None, 0, 0, 0, 0, 0, '{}', 0, 1)
# (182012, 1, 0, None, 'llegando a EAO', 10, None, None, 0, None, 0, 0, 0, 0, 0, '{}', 0, 1)
# (182013, 2, 0, '', None, 10, '/home/alopez/Documentos/ViberDownloads/0-02-01-4518ff90b737557aec0cb6fde183b97426d32e1870339dc9c1990f1970ced3b0_full.jpg', '/home/alopez/.ViberPC/525564994886/Thumbnails/thumb0-02-01-4518ff90b737557aec0cb6fde183b97426d32e1870339dc9c1990f1970ced3b0_full.jpg', 0, '0', 0, 0, 0, 0, 0, '{"fileInfo":{"ContentType":"PIC","Duration":0.0,"FileExt":"jpg","FileHash":"k9/ak2MrivMbo6OgnFM5hA\\u003d\\u003d","FileName":"IMG-3e1bb9c7ef217737d09cea9c1701fbad-V.jpg","mediaInfo":{"Height":2268,"MediaType":"image","Width":4032}},"pttVersion":0,"Type":"default"}', 0, 9)
# ...

# %%
cc = conn.execute("SELECT * from MessageInfo")

# %%
messageInfo = []

# %%
for row in cc:
    messageInfo.append(row)

# %%
len(messageInfo)
# Out:
# 176999

# %%
for i in range(175000,176999):
    print(messageInfo[i])
# Out:
# (182009, 1562878029873, 0, 0, 5330209631559362313, 5330209631559362313, 0, 1, 0, 0, 32, '4761235701444618285', 1, 0, None, 'saliendo de EAO', 10, 1, None, None, 0, None, 0, 0, 158, 0, 68, 0, 0, 0, '{}', 0, 1)
# (182010, 1562852382256, 0, 0, 5330102057513976856, 5330102057513976856, 0, 1, 0, 0, 32, '4761235701444618285', 1, 0, None, 'llegando a EAO', 10, 1, None, None, 0, None, 0, 0, 158, 0, 68, 0, 0, 0, '{}', 0, 1)
# (182011, 1562717810188, 0, 0, 5329537622147823958, 5329537622147823958, 0, 1, 0, 0, 32, '4761235701444618285', 1, 0, None, 'gracias compa descansa', 10, 1, None, None, 0, None, 0, 0, 155, 0, 68, 0, 0, 0, '{}', 0, 1)
# (182012, 1562717603415, 0, 0, 5329536755621397600, 5329536755621397600, 0, 1, 0, 0, 32, '4761235701444618285', 1, 0, None, 'llegando a EAO', 10, 1, None, None, 0, None, 0, 0, 158, 0, 68, 0, 0, 0, '{}', 0, 1)
# ...

# %%
ccc = conn.execute("SELECT * FROM Contact")

# %%
contact = []

# %%
for row in ccc:
    contact.append(row)

# %%
len(contact)
# Out:
# 269

# %%
for i in range(10):
    print(contact[i])
# Out:
# (1, None, 1, None, '+525564994886', 1, 'Ana Maria EAO DS', '0-03-01-a12125813116f91a5835ab9edcf5204d0e509be7e8db60072628ec497e4efc61', 'iK4c3WipBJzH9g4hTTOCHshYJEs=', 'dIpzW8TNExA=', None, 1)
# (2, 'Servicio', 1, None, '+525551072717', 1, 'Laura Gonzalez EAO', '0-03-01-da971c1d01ce9be064c151849bdd224e2fa4b34c86b0ccf7b1677bacd85e555e', 'p42EGYKkgETri5yT4RJNzI96mSY=', 'IVp/tpsPKVY=', None, 1)
# (3, None, 0, None, None, 1, 'HuffPost Entertainment', None, None, 'pa:4806500290462543003', None, 1)
# (4, None, 0, None, None, 1, 'WWF', None, None, 'pa:5022414291776936723', None, 1)
# (5, None, 0, None, None, 1, 'Shakira', None, None, 'pa:5057231171708257435', None, 1)
# (6, None, 0, None, '+525551446970', 1, 'Janett', '0-03-0a-122f36b3bbf9db2092cbb04cd4f613521c520509dcd4486cdb531ed33afbfa53', 'F6qb6sK+bKhy/OH1wIY5nvV21TA=', 'E+yiVqkBckg=', None, 1)
# ...
